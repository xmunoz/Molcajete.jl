# %%
using Molcajete
Molcajete.show_calendar("Julia-Users-Group", Date(2017, 1, 1), Date(2017, 1, 30), num_meetups = 20)
# Out:
# Fetching info for Julia-Users-Group meetup.
# Fetching meetup members.
# .................................................................
# Fetching events in date range.
# <div id="5fafe7d6-92c1-4357-b64d-eba85daf39a6" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
# ...
